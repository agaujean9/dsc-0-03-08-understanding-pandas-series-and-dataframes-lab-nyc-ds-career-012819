# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
df = df.rename(columns = lambda x: x.lower())

# %% [markdown]
# # Change the Index to be the Line Names

# %%
df.set_index('linename')
# Out:
#             c/a  unit       scp        station division        date      time  \
# linename
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  00:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  04:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  08:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  12:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  16:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  20:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  00:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  04:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  08:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  12:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  16:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  20:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/27/2018  00:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/27/2018  04:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/27/2018  08:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/27/2018  12:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/27/2018  16:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/27/2018  20:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/28/2018  00:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/28/2018  04:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/28/2018  08:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/28/2018  12:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/28/2018  16:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/28/2018  20:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/29/2018  00:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/29/2018  04:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/29/2018  08:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/29/2018  12:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/29/2018  16:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/29/2018  20:00:00
# ...         ...   ...       ...            ...      ...         ...       ...
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/27/2018  01:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/27/2018  05:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/27/2018  09:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/27/2018  13:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/27/2018  17:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/27/2018  21:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/28/2018  01:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/28/2018  05:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/28/2018  09:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/28/2018  13:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/28/2018  17:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/28/2018  21:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/29/2018  01:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/29/2018  05:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/29/2018  09:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/29/2018  13:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/29/2018  17:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/29/2018  21:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018  01:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018  05:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018  09:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018  13:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018  17:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/30/2018  21:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  01:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  05:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  09:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  13:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  17:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  21:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
# NQR456W   REGULAR  6736562
# NQR456W   REGULAR  6736683
# NQR456W   REGULAR  6736696
# NQR456W   REGULAR  6736705
# NQR456W   REGULAR  6736746
# NQR456W   REGULAR  6736873
# NQR456W   REGULAR  6737067
# NQR456W   REGULAR  6737136
# NQR456W   REGULAR  6737146
# NQR456W   REGULAR  6737169
# NQR456W   REGULAR  6737301
# NQR456W   REGULAR  6737553
# NQR456W   REGULAR  6738257
# NQR456W   REGULAR  6738430
# NQR456W   REGULAR  6738442
# NQR456W   REGULAR  6738474
# NQR456W   REGULAR  6738621
# NQR456W   REGULAR  6738886
# NQR456W   REGULAR  6739630
# NQR456W   REGULAR  6739804
# NQR456W   REGULAR  6739812
# NQR456W   REGULAR  6739847
# NQR456W   REGULAR  6739986
# NQR456W   REGULAR  6740257
# NQR456W   REGULAR  6740888
# ...           ...      ...
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
# R         REGULAR     5554
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384
# NQR456W                                             2283425
# NQR456W                                             2283460
# NQR456W                                             2283461
# NQR456W                                             2283483
# NQR456W                                             2283524
# NQR456W                                             2283587
# NQR456W                                             2283631
# NQR456W                                             2283656
# NQR456W                                             2283658
# NQR456W                                             2283736
# NQR456W                                             2283965
# NQR456W                                             2284025
# NQR456W                                             2284091
# NQR456W                                             2284121
# NQR456W                                             2284126
# NQR456W                                             2284216
# NQR456W                                             2284402
# NQR456W                                             2284425
# NQR456W                                             2284478
# NQR456W                                             2284508
# NQR456W                                             2284512
# NQR456W                                             2284600
# NQR456W                                             2284838
# NQR456W                                             2284896
# NQR456W                                             2284941
# ...                                                     ...
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
# R                                                       348
#
# [197625 rows x 10 columns]

# %% [markdown]
# # Painstakingly change the index back

# %%
# Your code here
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
# Your code here
df['Num_Lines'] = df.linename.map(lambda x: len(x))
df.head(5)
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines
# 0          7
# 1          7
# 2          7
# 3          7
# 4          7

# %%
# pd.to_datetime(df.date, format ='%m/%d/%Y') 
# df.date = pd.to_datetime(df.date)
# df.date = df.date.dt.day_name()
# Out:
# TypeErrorTraceback (most recent call last)
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueErrorTraceback (most recent call last)
# <ipython-input-54-d1c05e46cd5b> in <module>()
# ----> 1 pd.to_datetime(df.date, format ='%m/%d/%Y')
#       2 df.date = pd.to_datetime(df.date)
#       3 df.date = df.date.dt.day_name()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     449         else:
#     450             from pandas import Series
# --> 451             values = _convert_listlike(arg._values, True, format)
#     452             result = Series(values, index=arg.index, name=arg.name)
#     453     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     379             except (ValueError, TypeError):
# --> 380                 raise e
#     381
#     382     if arg is None:
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     345                     try:
#     346                         result = array_strptime(arg, format, exact=exact,
# --> 347                                                 errors=errors)
#     348                     except tslib.OutOfBoundsDatetime:
#     349                         if errors == 'raise':
#
# pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data 'Saturday' does not match format '%m/%d/%Y' (match)

# %%
df.head(20)
# Out:
#      c/a  unit       scp station linename division      date      time  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  Saturday  00:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  Saturday  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  Saturday  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  Saturday  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  Saturday  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  Saturday  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT    Sunday  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT    Sunday  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT    Sunday  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT    Sunday  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT    Sunday  16:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT    Sunday  20:00:00
# 12  A002  R051  02-00-00   59 ST  NQR456W      BMT    Monday  00:00:00
# 13  A002  R051  02-00-00   59 ST  NQR456W      BMT    Monday  04:00:00
# 14  A002  R051  02-00-00   59 ST  NQR456W      BMT    Monday  08:00:00
# 15  A002  R051  02-00-00   59 ST  NQR456W      BMT    Monday  12:00:00
# 16  A002  R051  02-00-00   59 ST  NQR456W      BMT    Monday  16:00:00
# 17  A002  R051  02-00-00   59 ST  NQR456W      BMT    Monday  20:00:00
# 18  A002  R051  02-00-00   59 ST  NQR456W      BMT   Tuesday  00:00:00
# 19  A002  R051  02-00-00   59 ST  NQR456W      BMT   Tuesday  04:00:00
#
#        desc  entries    exits  Num_Lines  Total_traffic
# 0   REGULAR  6736067  2283184          7        9019251
# 1   REGULAR  6736087  2283188          7        9019275
# 2   REGULAR  6736105  2283229          7        9019334
# 3   REGULAR  6736180  2283314          7        9019494
# 4   REGULAR  6736349  2283384          7        9019733
# 5   REGULAR  6736562  2283425          7        9019987
# 6   REGULAR  6736683  2283460          7        9020143
# 7   REGULAR  6736696  2283461          7        9020157
# 8   REGULAR  6736705  2283483          7        9020188
# 9   REGULAR  6736746  2283524          7        9020270
# 10  REGULAR  6736873  2283587          7        9020460
# 11  REGULAR  6737067  2283631          7        9020698
# 12  REGULAR  6737136  2283656          7        9020792
# 13  REGULAR  6737146  2283658          7        9020804
# 14  REGULAR  6737169  2283736          7        9020905
# 15  REGULAR  6737301  2283965          7        9021266
# 16  REGULAR  6737553  2284025          7        9021578
# 17  REGULAR  6738257  2284091          7        9022348
# 18  REGULAR  6738430  2284121          7        9022551
# 19  REGULAR  6738442  2284126          7        9022568

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.strip() 
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries', 'exits', 'Num_Lines', 'Total_traffic'],
# 21  REGULAR  6738621  2284402          7        9023023
# 22  REGULAR  6738886  2284425          7        9023311
# 23  REGULAR  6739630  2284478          7        9024108
# 24  REGULAR  6739804  2284508          7        9024312
# 25  REGULAR  6739812  2284512          7        9024324
# 26  REGULAR  6739847  2284600          7        9024447
# 27  REGULAR  6739986  2284838          7        9024824
# 28  REGULAR  6740257  2284896          7        9025153
# 29  REGULAR  6740888  2284941          7        9025829
# ..      ...      ...      ...        ...            ...
# 70  REGULAR  6030153  1350380          7        7380533
# 71  REGULAR  6030668  1350412          7        7381080
# 72  REGULAR  6030805  1350437          7        7381242
# 73  REGULAR  6030817  1350440          7        7381257
# 74  REGULAR  6030844  1350470          7        7381314
# 75  REGULAR  6030966  1350574          7        7381540
# 76  REGULAR  6031173  1350626          7        7381799
# 77  REGULAR  6031651  1350665          7        7382316
# 78  REGULAR  6031784  1350682          7        7382466
# 79  REGULAR  6031791  1350685          7        7382476
# 80  REGULAR  6031821  1350727          7        7382548
# 81  REGULAR  6031937  1350822          7        7382759
# 82  REGULAR  6032263  1350887          7        7383150
# 83  REGULAR  6032656  1350935          7        7383591
# 84  REGULAR  1117813  4176607          7        5294420
# 85  REGULAR  1117818  4176631          7        5294449
# 86  REGULAR  1117821  4176676          7        5294497
# 87  REGULAR  1117862  4176842          7        5294704
# 88  REGULAR  1117934  4177054          7        5294988
# 89  REGULAR  1118003  4177278          7        5295281
# 90  REGULAR  1118074  4177382          7        5295456
# 91  REGULAR  1118079  4177391          7        5295470
# 92  REGULAR  1118084  4177421          7        5295505
# 93  REGULAR  1118106  4177549          7        5295655
# 94  REGULAR  1118178  4177733          7        5295911
# 95  REGULAR  1118244  4177924          7        5296168
# 96  REGULAR  1118285  4178021          7        5296306
# 97  REGULAR  1118286  4178025          7        5296311
# 98  REGULAR  1118295  4178194          7        5296489
# 99  REGULAR  1118355  4178730          7        5297085
#
# [100 rows x 13 columns]

# %%
df.groupby('date').Total_traffic.sum()
# Out:
# date
# Friday       2017023765415
# Monday       2026175205967
# Saturday     2024803626988
# Sunday       2151529929543
# Thursday     2043415915772
# Tuesday      2085544008523
# Wednesday    2044286087128
# Name: Total_traffic, dtype: int64

# %%
df.groupby('date').Total_traffic.sum().plot(kind = 'bar')

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
#Your code here

# %% [markdown]
# # Drop a couple of columns

# %%
df = df.drop('division', axis=1)

# %%
df = df.drop('desc', axis=1)

# %%
df.head()
# Out:
#     c/a  unit       scp station linename      date      time  entries  \
# 0  A002  R051  02-00-00   59 ST  NQR456W  Saturday  00:00:00  6736067
# 1  A002  R051  02-00-00   59 ST  NQR456W  Saturday  04:00:00  6736087
# 2  A002  R051  02-00-00   59 ST  NQR456W  Saturday  08:00:00  6736105
# 3  A002  R051  02-00-00   59 ST  NQR456W  Saturday  12:00:00  6736180
# 4  A002  R051  02-00-00   59 ST  NQR456W  Saturday  16:00:00  6736349
#
#      exits  Num_Lines  Total_traffic
# 0  2283184          7        9019251
# 1  2283188          7        9019275
# 2  2283229          7        9019334
# 3  2283314          7        9019494
# 4  2283384          7        9019733
